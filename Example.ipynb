# %% [markdown]
# # Getting recommendations
#
# **Important**: Make sure you have a csv of your zotero library and a text file with your feedly client token in the inputs folder.

# %%
from article_recommender.load_zotero import ZoteroLibrary
from article_recommender.training import TrainingData
from article_recommender.feedly_connector import FeedlyStream

# %% [markdown]
# If you have never loaded the nltk stopwords corpus before run the code below:

# %%
import nltk
nltk.download('stopwords')

# %% [markdown]
# First load your zotero library.

# %%
library = ZoteroLibrary()
library.read_library('inputs/zotero_library.csv')

# %% [markdown]
# Load the library into a training data set.

# %%
train_data = TrainingData(library.get_library())

# %% [markdown]
# Train a count vectorizer (bag of words) based on the training data to prepare for scoring articles.

# %%
train_data.train_vectorizer();

# %% [markdown]
# Load articles from feedly that you would like to score. Category should be the category on feedly where you put your journal article feeds. You can load up to 1000 articles per stream (rss feed). You can also load multiple categories by running the load_category function for each category.

# %%
# %%capture 
# ^^ Hides the SSL warnings from the requests library
with open('inputs/feedly_client_token.txt', 'r') as f:
    FEEDLY_CLIENT_TOKEN = f.readline()

rss_articles = FeedlyStream(FEEDLY_CLIENT_TOKEN)
rss_articles.load_category(category='Journals', articles_per_stream=20);

# %% [markdown]
# Rank all the articles in loaded categories based on the trained vectorizer from train_data. The result is a pandas data frame that can be further manipulated or output to a file.

# %%
results = rss_articles.rank_all(train_data)
results
# Out:
#                                                  Title  \
# 0                  Organic transistors: Holey contacts
# 1                  Magnetic materials: Optical control
# 2             High-harmonic generation: To the extreme
# 3          Polymer substrates: Supporting pluripotency
# 4           2D materials: Charge density waves go nano
# 5    The effect of mechanical twisting on oxygen io...
# 6    Strongly enhanced charge-density-wave order in...
# 7      High-harmonic generation: Drive round the twist
# 8    Magnetoluminescence and valley polarized state...
# 9    Quantum oscillations in a two-dimensional elec...
# 10   Single-atom imaging of fermions in a quantum-g...
# 11   Exchange bias and room-temperature magnetic or...
# 12   Gating a single-molecule transistor with indiv...
# 13      Quantum Hamiltonian complexity: Worth the wait
# 14   Phonon wave interference and thermal bandgap m...
# 15            Photodetectors: Low-cost X-ray detectors
# 16   Observation of a robust zero-energy bound stat...
# 17   Large anelasticity and associated energy dissi...
# 18       Metamaterials: Steering surface plasmon wakes
# 19   Edge-mode superconductivity in a two-dimension...
# 20   Polarization charge as a reconfigurable quasi-...
# 21   Probing molecular chirality on a sub-femtoseco...
# 22   Room-temperature single-photon generation from...
# 23           Quasicrystals: Making invisible materials
# 24   Spatially resolved ultrafast magnetic dynamics...
# 25   Water transport inside carbon nanotubes mediat...
# 26   Spontaneously broken time-reversal symmetry in...
# 27    Two-dimensional materials: Lift off for graphene
# 28        Perovskite photovoltaics: Signs of stability
# 29   Direct measurement of the exciton binding ener...
# ..                                                 ...
# 132   Russia's crackdowns are jeopardizing its science
# 133  Symmetry and scale orient Min protein patterns...
# 134  Conservation: Stop misuse of biodiversity offsets
# 135        Astronomy: Total eclipse of rare twin stars
# 136                          [Feature] No end in sight
# 137  Pressure-induced superconductivity in the iron...
# 138  Synthesis of nanostructures in nanowires using...
# 139  Secondary reconnection sites in reconnection-g...
# 140  Anthropology: Earliest signs of chicken husbandry
# 141                                    Timeless advice
# 142              Science fiction: Star-flight dreaming
# 143                                    No walking away
# 144  An environmentally benign antimicrobial nanopa...
# 145      [In Depth] Torture report prompts APA apology
# 146                                  The truth phalanx
# 147  Detection of X-ray photons by solution-process...
# 148             [In Depth] Russia targets Western ties
# 149  Translation correlations in anisotropically sc...
# 150                      [Books et al.] Books Received
# 151   Evolution: Hands hold clues to primate evolution
# 152           Mathematics: The mercurial mathematician
# 153                         [Book Review] Virtual love
# 154  [Letter] Geological evidence for the Anthropocene
# 155              [Editorial] Passion is just the start
# 156                     Syringe-injectable electronics
# 157  Accessing the fundamentals of magnetotransport...
# 158  Environmental science: Agree on biodiversity m...
# 159  Graphene on hexagonal boron nitride as a tunab...
# 160                  [Letter] Holocene as Anthropocene
# 161  Dislocation locking versus easy glide in titan...
#
#                                                    Url      Score
# 0    http://feeds.nature.com/~r/nmat/rss/current/~3...  36.555556
# 1    http://feeds.nature.com/~r/nphoton/rss/current...  35.111111
# 2    http://feeds.nature.com/~r/nphys/rss/current/~...  30.217391
# 3    http://feeds.nature.com/~r/nmat/rss/current/~3...  29.000000
# 4    http://feeds.nature.com/~r/nnano/rss/aop/~3/qK...  28.125000
# 5    http://feeds.nature.com/~r/nmat/rss/current/~3...  27.312500
# 6    http://feeds.nature.com/~r/nnano/rss/aop/~3/9D...  27.080645
# 7    http://feeds.nature.com/~r/nphys/rss/aop/~3/Se...  26.043478
# 8    http://feeds.nature.com/~r/nnano/rss/current/~...  25.921739
# 9    http://feeds.nature.com/~r/nnano/rss/current/~...  25.727273
# 10   http://feeds.nature.com/~r/nphys/rss/aop/~3/VP...  23.647619
# 11   http://feeds.nature.com/~r/nmat/rss/aop/~3/D-h...  23.173913
# 12   http://feeds.nature.com/~r/nphys/rss/aop/~3/6X...  22.347107
# 13   http://feeds.nature.com/~r/nphys/rss/current/~...  21.933333
# 14   http://feeds.nature.com/~r/nmat/rss/current/~3...  21.636364
# 15   http://feeds.nature.com/~r/nphoton/rss/current...  20.076923
# 16   http://feeds.nature.com/~r/nphys/rss/current/~...  19.640351
# 17   http://feeds.nature.com/~r/nnano/rss/aop/~3/Zj...  19.246575
# 18   http://feeds.nature.com/~r/nnano/rss/aop/~3/A8...  18.904762
# 19   http://feeds.nature.com/~r/nnano/rss/current/~...  18.638095
# 20   http://feeds.nature.com/~r/nnano/rss/current/~...  18.460432
# 21   http://feeds.nature.com/~r/nphys/rss/aop/~3/FR...  18.087379
# 22   http://feeds.nature.com/~r/nnano/rss/aop/~3/qB...  17.904412
# 23   http://feeds.nature.com/~r/nphoton/rss/current...  17.866667
# 24   http://feeds.nature.com/~r/nmat/rss/aop/~3/Ao2...  17.727273
# 25   http://feeds.nature.com/~r/nnano/rss/aop/~3/lG...  17.617021
# 26   http://feeds.nature.com/~r/nphys/rss/aop/~3/fq...  17.538462
# 27   http://feeds.nature.com/~r/nphoton/rss/current...  17.400000
# 28   http://feeds.nature.com/~r/nnano/rss/current/~...  17.380952
# 29   http://feeds.nature.com/~r/nphys/rss/current/~...  17.162162
# ..                                                 ...        ...
# 132  http://feeds.nature.com/~r/nature/rss/current/...   3.181818
# 133  http://feeds.nature.com/~r/nnano/rss/aop/~3/XJ...   3.142857
# 134  http://feeds.nature.com/~r/nature/rss/current/...   3.142857
# 135  http://feeds.nature.com/~r/nature/rss/current/...   3.062500
# 136  http://www.sciencemag.org/content/349/6245/230...   2.940171
# 137  http://feeds.nature.com/~r/nmat/rss/aop/~3/60s...   2.906977
# 138  http://feeds.nature.com/~r/nmat/rss/aop/~3/bjN...   2.840000
# 139  http://feeds.nature.com/~r/nphys/rss/aop/~3/bS...   2.785714
# 140  http://feeds.nature.com/~r/nature/rss/current/...   2.771429
# 141  http://feeds.nature.com/~r/nature/rss/current/...   2.500000
# 142  http://feeds.nature.com/~r/nature/rss/current/...   2.500000
# 143  http://feeds.nature.com/~r/nnano/rss/current/~...   2.142857
# 144  http://feeds.nature.com/~r/nnano/rss/aop/~3/NX...   1.944444
# 145  http://www.sciencemag.org/content/349/6245/221...   1.840580
# 146  http://feeds.nature.com/~r/nphys/rss/current/~...   1.650000
# 147  http://feeds.nature.com/~r/nphoton/rss/current...   1.611111
# 148  http://www.sciencemag.org/content/349/6245/224...   1.432990
# 149  http://feeds.nature.com/~r/nphys/rss/aop/~3/Ve...   1.263158
# 150  http://www.sciencemag.org/content/349/6245/244...   1.230769
# 151  http://feeds.nature.com/~r/nature/rss/current/...   0.800000
# 152  http://feeds.nature.com/~r/nature/rss/current/...   0.733333
# 153  http://www.sciencemag.org/content/349/6245/243...   0.650000
# 154  http://www.sciencemag.org/content/349/6245/246...   0.636364
# 155  http://www.sciencemag.org/content/349/6245/217...   0.604651
# 156  http://feeds.nature.com/~r/nnano/rss/current/~...   0.424242
# 157  http://feeds.nature.com/~r/nphys/rss/aop/~3/Pg...   0.379310
# 158  http://feeds.nature.com/~r/nature/rss/current/...   0.295455
# 159  http://feeds.nature.com/~r/nnano/rss/aop/~3/Rk...   0.222222
# 160  http://www.sciencemag.org/content/349/6245/246...   0.000000
# 161  http://feeds.nature.com/~r/nmat/rss/aop/~3/HKZ...   0.000000
#
# [162 rows x 3 columns]
