# %% [markdown]
# # Getting recommendations
#
# **Important**: Make sure you have a csv of your zotero library and a text file with your feedly client token in the inputs folder.

# %%
from article_recommender.load_zotero import ZoteroLibrary
from article_recommender.training import TrainingData
from article_recommender.feedly_connector import FeedlyStream

# %% [markdown]
# If you have never loaded the nltk stopwords corpus before run the code below:

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/steve/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# First load your zotero library.

# %%
library = ZoteroLibrary()
library.read_library('inputs/zotero_library.csv')

# %% [markdown]
# Load the library into a training data set.

# %%
train_data = TrainingData(library.get_library())

# %% [markdown]
# Train a count vectorizer (bag of words) based on the training data to prepare for scoring articles.

# %%
train_data.train_count_vectorizer();

# %% [markdown]
# Load articles from feedly that you would like to score. Category should be the category on feedly where you put your journal article feeds. You can load up to 1000 articles per stream (rss feed). You can also load multiple categories by running the load_category function for each category.

# %%
# %%capture 
# ^^ Hides the SSL warnings from the requests library
with open('inputs/feedly_client_token.txt', 'r') as f:
    FEEDLY_CLIENT_TOKEN = f.readline()

rss_articles = FeedlyStream(FEEDLY_CLIENT_TOKEN)
rss_articles.load_category(category='Journals', articles_per_stream=100);

# %% [markdown]
# Rank all the articles in loaded categories based on the trained vectorizer from train_data. The result is a pandas data frame that can be further manipulated or output to a file.

# %%
results = rss_articles.rank_all(train_data)
results
# Out:
# /Users/steve/anaconda/lib/python2.7/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
#                                                  Title  \
# 0            Materials: Better battery with more juice
# 1    2D superconductivity: Electric tuning of many-...
# 2    A quantum phase switch between a single solid-...
# 3      Light–matter interaction: Nano-optical isolator
# 4                        The rise of quantum materials
# 5                            Imaging: Nano meets femto
# 6                  The surface science of nanocrystals
# 7             Infrared spectroscopy with visible light
# 8         Spintronics: Nanomagnonics around the corner
# 9    Climate and energy challenges for materials sc...
# 10   Non-classical correlations between single phot...
# 11   High-gain infrared-to-visible upconversion lig...
# 12   Laser cooling of organic–inorganic lead halide...
# 13   The classical and quantum dynamics of molecula...
# 14                 Quantum optics: Spooky spectroscopy
# 15   Wavefunction-based electronic-structure calcul...
# 16             Lattice assembly: Patterned by polymers
# 17   Electrical control of the valley Hall effect i...
# 18   Terahertz modulation of the Faraday rotation b...
# 19                     Chiral magnetic effect in ZrTe5
# 20   Magnetic domain walls as reconfigurable spin-w...
# 21   [Report] Nuclear magnetic resonance detection ...
# 22                          Building a better nanopore
# 23   Spin-torque nano-oscillators: Geometrical sync...
# 24        Quantum physics: Photons paired with phonons
# 25     Correlated oxides: Metals amassing transparency
# 26   Two-dimensional superconductivity: The Ising o...
# 27   Programming curvature using origami tessellations
# 28   A reconfigurable waveguide for energy-efficien...
# 29                 Thermoelectrics: Ranged performance
# ..                                                 ...
# 290  Parasitology: Honeybee virus spread by human a...
# 291  [This Week in Science] A route to nitrile that...
# 292  [This Week in Science] An unconventional route...
# 293  [This Week in Science] The real cause of cance...
# 294              [This Week in Science] How stars grow
# 295           [This Week in Science] By land or by sea
# 296  [This Week in Science] Crowdsourcing earthquak...
# 297  [This Week in Science] Killing cancer with a s...
# 298  [This Week in Science] Insight into a bacteria...
# 299  [This Week in Science] Preparing for the next ...
# 300  [This Week in Science] The SAGA of removing nu...
# 301                               A bridge to business
# 302  [This Week in Science] The yin and yang of pro...
# 303  [This Week in Science] The legacy of human-Nea...
# 304  [This Week in Science] Parasitic DNAs help and...
# 305  [Errata] Erratum for the Report “Ancient Ethio...
# 306        [Letter] The crushing weight of urban waste
# 307   [Letter] Plant scientists: GM technology is safe
# 308  Intraoperative diagnostics and elimination of ...
# 309        Correlated metals as transparent conductors
# 310          [Letter] Protect the Tasmanian wilderness
# 311                   [Letter] Teaching trust with art
# 312  [Editors' Choice] Dissolution in the Southern ...
# 313  [Editors' Choice] Gauging vulnerability to wat...
# 314  [Editors' Choice] Tuning down an overactive th...
# 315  [Editors' Choice] Shared knowledge as the basi...
# 316  [Editors' Choice] Placing the catalyst where i...
# 317  [Editors' Choice] Hair-trigger sensitivities i...
# 318  A transparent bending-insensitive pressure sensor
# 319       Drug discovery: A life of tumult and triumph
#
#                                                    Url     Score
# 0    http://feeds.nature.com/~r/nature/rss/current/...  0.041554
# 1    http://feeds.nature.com/~r/nnano/rss/current/~...  0.039969
# 2    http://feeds.nature.com/~r/nnano/rss/aop/~3/bG...  0.039717
# 3    http://feeds.nature.com/~r/nphoton/rss/current...  0.033098
# 4    http://feeds.nature.com/~r/nphys/rss/current/~...  0.031172
# 5    http://feeds.nature.com/~r/nnano/rss/aop/~3/iQ...  0.030744
# 6    http://feeds.nature.com/~r/nmat/rss/current/~3...  0.029788
# 7    http://feeds.nature.com/~r/nphoton/rss/current...  0.029716
# 8    http://feeds.nature.com/~r/nnano/rss/aop/~3/7C...  0.029644
# 9    http://feeds.nature.com/~r/nmat/rss/current/~3...  0.027985
# 10   http://feeds.nature.com/~r/nature/rss/current/...  0.027583
# 11   http://feeds.nature.com/~r/nphoton/rss/current...  0.027395
# 12   http://feeds.nature.com/~r/nphoton/rss/current...  0.027140
# 13   http://feeds.nature.com/~r/nmat/rss/current/~3...  0.026825
# 14   http://feeds.nature.com/~r/nphoton/rss/current...  0.026625
# 15   http://feeds.nature.com/~r/nphys/rss/current/~...  0.026520
# 16   http://feeds.nature.com/~r/nmat/rss/current/~3...  0.026331
# 17   http://feeds.nature.com/~r/nnano/rss/aop/~3/8V...  0.025543
# 18   http://feeds.nature.com/~r/nphoton/rss/current...  0.024781
# 19   http://feeds.nature.com/~r/nphys/rss/aop/~3/9T...  0.024438
# 20   http://feeds.nature.com/~r/nnano/rss/aop/~3/w5...  0.024372
# 21   http://science.sciencemag.org/content/351/6275...  0.023926
# 22   http://feeds.nature.com/~r/nnano/rss/current/~...  0.023919
# 23   http://feeds.nature.com/~r/nmat/rss/current/~3...  0.023349
# 24   http://feeds.nature.com/~r/nature/rss/current/...  0.023328
# 25   http://feeds.nature.com/~r/nmat/rss/current/~3...  0.023219
# 26   http://feeds.nature.com/~r/nphys/rss/current/~...  0.022877
# 27   http://feeds.nature.com/~r/nmat/rss/aop/~3/S5o...  0.022109
# 28   http://feeds.nature.com/~r/nnano/rss/aop/~3/jd...  0.021977
# 29   http://feeds.nature.com/~r/nmat/rss/current/~3...  0.021844
# ..                                                 ...       ...
# 290  http://feeds.nature.com/~r/nature/rss/current/...  0.001551
# 291  http://science.sciencemag.org/content/351/6275...  0.001324
# 292  http://science.sciencemag.org/content/351/6274...  0.001324
# 293  http://science.sciencemag.org/content/351/6275...  0.001204
# 294  http://science.sciencemag.org/content/351/6274...  0.000827
# 295  http://science.sciencemag.org/content/351/6274...  0.000736
# 296  http://science.sciencemag.org/content/351/6275...  0.000662
# 297  http://science.sciencemag.org/content/351/6275...  0.000662
# 298  http://science.sciencemag.org/content/351/6275...  0.000662
# 299  http://science.sciencemag.org/content/351/6275...  0.000662
# 300  http://science.sciencemag.org/content/351/6274...  0.000662
# 301  http://feeds.nature.com/~r/nature/rss/current/...  0.000611
# 302  http://science.sciencemag.org/content/351/6275...  0.000602
# 303  http://science.sciencemag.org/content/351/6274...  0.000602
# 304  http://science.sciencemag.org/content/351/6274...  0.000602
# 305  http://science.sciencemag.org/content/351/6275...  0.000591
# 306  http://science.sciencemag.org/content/351/6274...  0.000557
# 307  http://science.sciencemag.org/content/351/6275...  0.000458
# 308  http://feeds.nature.com/~r/nnano/rss/aop/~3/Xo...  0.000236
# 309  http://feeds.nature.com/~r/nmat/rss/current/~3...  0.000185
# 310  http://science.sciencemag.org/content/351/6275...  0.000000
# 311  http://science.sciencemag.org/content/351/6275...  0.000000
# 312  http://science.sciencemag.org/content/351/6275...  0.000000
# 313  http://science.sciencemag.org/content/351/6275...  0.000000
# 314  http://science.sciencemag.org/content/351/6275...  0.000000
# 315  http://science.sciencemag.org/content/351/6275...  0.000000
# 316  http://science.sciencemag.org/content/351/6275...  0.000000
# 317  http://science.sciencemag.org/content/351/6275...  0.000000
# 318  http://feeds.nature.com/~r/nnano/rss/aop/~3/Ga...  0.000000
# 319  http://feeds.nature.com/~r/nature/rss/current/...  0.000000
#
# [320 rows x 3 columns]

# %% [markdown]
# ## Same as above but with the tf-idf vectorizer (term frequency inverse document frequency)

# %%
train_data.train_tfidf_vectorizer();

# %%
tfidf_results = rss_articles.rank_all(train_data, vectorizer='tfidf')
tfidf_results
# Out:
#                                                  Title  \
# 0    [Report] Nuclear magnetic resonance detection ...
# 1    Femtosecond two-photon Rabi oscillations in ex...
# 2    Strong interplay between stripe spin fluctuati...
# 3                      Chiral magnetic effect in ZrTe5
# 4    Magnetic domain walls as reconfigurable spin-w...
# 5    A new active Li–Mn–O compound for high energy ...
# 6    Electrical control of the valley Hall effect i...
# 7    Structure- and function-based design of Plasmo...
# 8    Femtosecond and nanometre visualization of str...
# 9    Critical spin fluctuations and the origin of n...
# 10   Oxygen-activated growth and bandgap tunability...
# 11   Non-classical correlations between single phot...
# 12   Macromolecular diffractive imaging using imper...
# 13   A biomimetic DNA-based channel for the ligand-...
# 14   The classical and quantum dynamics of molecula...
# 15   2D superconductivity: Electric tuning of many-...
# 16   A novel quasi-one-dimensional topological insu...
# 17   Terahertz modulation of the Faraday rotation b...
# 18   Organically linked iron oxide nanoparticle sup...
# 19   Effector T-cell trafficking between the leptom...
# 20   Hoxb5 marks long-term haematopoietic stem cell...
# 21           Materials: Better battery with more juice
# 22   [Report] 2.3 Å resolution cryo-EM structure of...
# 23                       The rise of quantum materials
# 24      [Perspective] Copper catalysis in a blue light
# 25   A structural approach to relaxation in glassy ...
# 26   [Report] DNA-controlled dynamic colloidal nano...
# 27     On the growth and form of cortical convolutions
# 28   Single-shot simulations of dynamic quantum man...
# 29                          Building a better nanopore
# ..                                                 ...
# 290  [This Week in Science] Stacking to prolong val...
# 291  [This Week in Science] Dynamic DNA clustering ...
# 292   [Letter] Plant scientists: GM technology is safe
# 293  [This Week in Science] A route to nitrile that...
# 294  [This Week in Science] An unconventional route...
# 295  Intraoperative diagnostics and elimination of ...
# 296  [This Week in Science] The real cause of cance...
# 297        [Letter] The crushing weight of urban waste
# 298        Correlated metals as transparent conductors
# 299                               A bridge to business
# 300  [This Week in Science] Crowdsourcing earthquak...
# 301  [This Week in Science] Killing cancer with a s...
# 302  [This Week in Science] The yin and yang of pro...
# 303  [This Week in Science] Insight into a bacteria...
# 304  [This Week in Science] Preparing for the next ...
# 305  [This Week in Science] The SAGA of removing nu...
# 306  [This Week in Science] The legacy of human-Nea...
# 307           [This Week in Science] By land or by sea
# 308              [This Week in Science] How stars grow
# 309  [This Week in Science] Parasitic DNAs help and...
# 310          [Letter] Protect the Tasmanian wilderness
# 311                   [Letter] Teaching trust with art
# 312  [Editors' Choice] Dissolution in the Southern ...
# 313  [Editors' Choice] Gauging vulnerability to wat...
# 314  [Editors' Choice] Tuning down an overactive th...
# 315  [Editors' Choice] Shared knowledge as the basi...
# 316  [Editors' Choice] Placing the catalyst where i...
# 317  [Editors' Choice] Hair-trigger sensitivities i...
# 318  A transparent bending-insensitive pressure sensor
# 319       Drug discovery: A life of tumult and triumph
#
#                                                    Url     Score
# 0    http://science.sciencemag.org/content/351/6275...  0.247174
# 1    http://feeds.nature.com/~r/nphoton/rss/current...  0.232034
# 2    http://feeds.nature.com/~r/nmat/rss/current/~3...  0.231861
# 3    http://feeds.nature.com/~r/nphys/rss/aop/~3/9T...  0.220659
# 4    http://feeds.nature.com/~r/nnano/rss/aop/~3/w5...  0.215602
# 5    http://feeds.nature.com/~r/nmat/rss/current/~3...  0.215486
# 6    http://feeds.nature.com/~r/nnano/rss/aop/~3/8V...  0.214571
# 7    http://feeds.nature.com/~r/nature/rss/current/...  0.208822
# 8    http://feeds.nature.com/~r/nphoton/rss/current...  0.206568
# 9    http://feeds.nature.com/~r/nphys/rss/aop/~3/fV...  0.201043
# 10   http://feeds.nature.com/~r/nnano/rss/aop/~3/4S...  0.200463
# 11   http://feeds.nature.com/~r/nature/rss/current/...  0.197416
# 12   http://feeds.nature.com/~r/nature/rss/current/...  0.196599
# 13   http://feeds.nature.com/~r/nnano/rss/current/~...  0.196571
# 14   http://feeds.nature.com/~r/nmat/rss/current/~3...  0.192636
# 15   http://feeds.nature.com/~r/nnano/rss/current/~...  0.187453
# 16   http://feeds.nature.com/~r/nmat/rss/current/~3...  0.186901
# 17   http://feeds.nature.com/~r/nphoton/rss/current...  0.178989
# 18   http://feeds.nature.com/~r/nmat/rss/aop/~3/NvO...  0.178921
# 19   http://feeds.nature.com/~r/nature/rss/current/...  0.175961
# 20   http://feeds.nature.com/~r/nature/rss/current/...  0.173701
# 21   http://feeds.nature.com/~r/nature/rss/current/...  0.172958
# 22   http://science.sciencemag.org/content/351/6275...  0.171093
# 23   http://feeds.nature.com/~r/nphys/rss/current/~...  0.167162
# 24   http://science.sciencemag.org/content/351/6274...  0.166713
# 25   http://feeds.nature.com/~r/nphys/rss/aop/~3/KA...  0.165957
# 26   http://science.sciencemag.org/content/351/6275...  0.164606
# 27   http://feeds.nature.com/~r/nphys/rss/aop/~3/q_...  0.163516
# 28   http://feeds.nature.com/~r/nphys/rss/aop/~3/HW...  0.163313
# 29   http://feeds.nature.com/~r/nnano/rss/current/~...  0.162140
# ..                                                 ...       ...
# 290  http://science.sciencemag.org/content/351/6274...  0.020483
# 291  http://science.sciencemag.org/content/351/6275...  0.017937
# 292  http://science.sciencemag.org/content/351/6275...  0.017926
# 293  http://science.sciencemag.org/content/351/6275...  0.017083
# 294  http://science.sciencemag.org/content/351/6274...  0.017083
# 295  http://feeds.nature.com/~r/nnano/rss/aop/~3/Xo...  0.014933
# 296  http://science.sciencemag.org/content/351/6275...  0.012749
# 297  http://science.sciencemag.org/content/351/6274...  0.012588
# 298  http://feeds.nature.com/~r/nmat/rss/current/~3...  0.012231
# 299  http://feeds.nature.com/~r/nature/rss/current/...  0.008530
# 300  http://science.sciencemag.org/content/351/6275...  0.006762
# 301  http://science.sciencemag.org/content/351/6275...  0.006762
# 302  http://science.sciencemag.org/content/351/6275...  0.006762
# 303  http://science.sciencemag.org/content/351/6275...  0.006762
# 304  http://science.sciencemag.org/content/351/6275...  0.006762
# 305  http://science.sciencemag.org/content/351/6274...  0.006762
# 306  http://science.sciencemag.org/content/351/6274...  0.006762
# 307  http://science.sciencemag.org/content/351/6274...  0.006762
# 308  http://science.sciencemag.org/content/351/6274...  0.006762
# 309  http://science.sciencemag.org/content/351/6274...  0.006762
# 310  http://science.sciencemag.org/content/351/6275...  0.000000
# 311  http://science.sciencemag.org/content/351/6275...  0.000000
# 312  http://science.sciencemag.org/content/351/6275...  0.000000
# 313  http://science.sciencemag.org/content/351/6275...  0.000000
# 314  http://science.sciencemag.org/content/351/6275...  0.000000
# 315  http://science.sciencemag.org/content/351/6275...  0.000000
# 316  http://science.sciencemag.org/content/351/6275...  0.000000
# 317  http://science.sciencemag.org/content/351/6275...  0.000000
# 318  http://feeds.nature.com/~r/nnano/rss/aop/~3/Ga...  0.000000
# 319  http://feeds.nature.com/~r/nature/rss/current/...  0.000000
#
# [320 rows x 3 columns]
