# %% [markdown]
# # Getting recommendations
#
# **Important**: Make sure you have a csv of your zotero library and a text file with your feedly client token in the inputs folder.

# %%
from article_recommender.load_zotero import ZoteroLibrary
from article_recommender.training import TrainingData
from article_recommender.feedly_connector import FeedlyStream

# %% [markdown]
# First load your zotero library.

# %%
library = ZoteroLibrary()
library.read_library('inputs/zotero_library.csv')

# %% [markdown]
# Load the library into a training data set.

# %%
train_data = TrainingData(library.get_library())

# %% [markdown]
# Train a count vectorizer (bag of words) based on the training data to prepare for scoring articles.

# %%
train_data.train_vectorizer();

# %% [markdown]
# Load articles from feedly that you would like to score. Category should be the category on feedly where you put your journal article feeds. You can load up to 1000 articles per stream (rss feed). You can also load multiple categories by running the load_category function for each category.

# %%
# %%capture 
# ^^ Hides the SSL warnings from the requests library
with open('inputs/feedly_client_token.txt', 'r') as f:
    FEEDLY_CLIENT_TOKEN = f.readline()

rss_articles = FeedlyStream(FEEDLY_CLIENT_TOKEN)
rss_articles.load_category(category='Journals', articles_per_stream=20);

# %% [markdown]
# Rank all the articles in loaded categories based on the trained vectorizer from train_data. The result is a pandas data frame that can be further manipulated or output to a file.

# %%
results = rss_articles.rank_all(train_data)
results
# Out:
#                                                  Title  \
# 0                  Organic transistors: Holey contacts
# 1                  Magnetic materials: Optical control
# 2             High-harmonic generation: To the extreme
# 3             High-harmonic generation: To the extreme
# 4          Polymer substrates: Supporting pluripotency
# 5    The effect of mechanical twisting on oxygen io...
# 6      High-harmonic generation: Drive round the twist
# 7    Magnetoluminescence and valley polarized state...
# 8    Quantum oscillations in a two-dimensional elec...
# 9          Bright visible light emission from graphene
# 10   Enhancement of low-energy electron emission in...
# 11      Quantum Hamiltonian complexity: Worth the wait
# 12       Cancer treatment: Low-energy electron therapy
# 13   Phonon wave interference and thermal bandgap m...
# 14   Resonant internal quantum transitions and femt...
# 15            Photodetectors: Low-cost X-ray detectors
# 16   Observation of a robust zero-energy bound stat...
# 17   Observation of a robust zero-energy bound stat...
# 18       Metamaterials: Steering surface plasmon wakes
# 19   Edge-mode superconductivity in a two-dimension...
# 20   Polarization charge as a reconfigurable quasi-...
# 21   Polarization charge as a reconfigurable quasi-...
# 22   Probing molecular chirality on a sub-femtoseco...
# 23           Quasicrystals: Making invisible materials
# 24   Spatially resolved ultrafast magnetic dynamics...
# 25   Water transport inside carbon nanotubes mediat...
# 26   Spontaneously broken time-reversal symmetry in...
# 27    Two-dimensional materials: Lift off for graphene
# 28        Perovskite photovoltaics: Signs of stability
# 29              Physics: Tighter limits on dark matter
# ..                                                 ...
# 138                 The week in science: 3–9 July 2015
# 139            Quick lessons on environmental nanotech
# 140                     [Book Review] The safety dance
# 141  Symmetry and scale orient Min protein patterns...
# 142                  The 24/7 search for killer quakes
# 143                                        Cloud cover
# 144  European labs set sights on continent-wide com...
# 145               Particle physics: Inside the Rad Lab
# 146                                     Books in brief
# 147  [In Depth] Scientists dread Greek exit from th...
# 148  [Perspective] Intellectuals and the rise of th...
# 149  Synthesis of nanostructures in nanowires using...
# 150                     Physics: The impulse of beauty
# 151  [Policy Forum] Managing mining of the deep seabed
# 152                                     A numbers game
# 153           Plant science: A gene for evening scents
# 154                                    No walking away
# 155                [Book Review] Beachcomber's delight
# 156  Fractal heterogeneity in minimal matrix models...
# 157                                  The truth phalanx
# 158  Detection of X-ray photons by solution-process...
# 159  Biomechanics: Seahorses benefit from square tails
# 160  Translation correlations in anisotropically sc...
# 161                      [Books et al.] Books Received
# 162            Virology: Mapping viral disease vectors
# 163                     Syringe-injectable electronics
# 164  Accessing the fundamentals of magnetotransport...
# 165  Graphene on hexagonal boron nitride as a tunab...
# 166    Conservation: Amazon wildlife hit by hydropower
# 167  Dislocation locking versus easy glide in titan...
#
#                                                    Url      Score
# 0    http://feeds.nature.com/~r/nmat/rss/current/~3...  36.555556
# 1    http://feeds.nature.com/~r/nphoton/rss/current...  35.111111
# 2    http://feeds.nature.com/~r/nphys/rss/aop/~3/Hm...  30.217391
# 3    http://feeds.nature.com/~r/nphys/rss/current/~...  30.217391
# 4    http://feeds.nature.com/~r/nmat/rss/current/~3...  29.000000
# 5    http://feeds.nature.com/~r/nmat/rss/current/~3...  27.312500
# 6    http://feeds.nature.com/~r/nphys/rss/aop/~3/Se...  26.043478
# 7    http://feeds.nature.com/~r/nnano/rss/current/~...  25.921739
# 8    http://feeds.nature.com/~r/nnano/rss/current/~...  25.727273
# 9    http://feeds.nature.com/~r/nnano/rss/aop/~3/H_...  23.045455
# 10   http://feeds.nature.com/~r/nmat/rss/aop/~3/1Cg...  22.093750
# 11   http://feeds.nature.com/~r/nphys/rss/current/~...  21.933333
# 12   http://feeds.nature.com/~r/nmat/rss/aop/~3/oTb...  21.821429
# 13   http://feeds.nature.com/~r/nmat/rss/current/~3...  21.636364
# 14   http://feeds.nature.com/~r/nmat/rss/aop/~3/MTN...  20.938462
# 15   http://feeds.nature.com/~r/nphoton/rss/current...  20.076923
# 16   http://feeds.nature.com/~r/nphys/rss/aop/~3/Aj...  19.640351
# 17   http://feeds.nature.com/~r/nphys/rss/current/~...  19.640351
# 18   http://feeds.nature.com/~r/nnano/rss/aop/~3/A8...  18.904762
# 19   http://feeds.nature.com/~r/nnano/rss/current/~...  18.638095
# 20   http://feeds.nature.com/~r/nnano/rss/aop/~3/S1...  18.460432
# 21   http://feeds.nature.com/~r/nnano/rss/current/~...  18.460432
# 22   http://feeds.nature.com/~r/nphys/rss/aop/~3/FR...  18.087379
# 23   http://feeds.nature.com/~r/nphoton/rss/current...  17.866667
# 24   http://feeds.nature.com/~r/nmat/rss/aop/~3/Ao2...  17.727273
# 25   http://feeds.nature.com/~r/nnano/rss/aop/~3/lG...  17.617021
# 26   http://feeds.nature.com/~r/nphys/rss/aop/~3/fq...  17.538462
# 27   http://feeds.nature.com/~r/nphoton/rss/current...  17.400000
# 28   http://feeds.nature.com/~r/nnano/rss/current/~...  17.380952
# 29   http://feeds.nature.com/~r/nature/rss/current/...  17.189189
# ..                                                 ...        ...
# 138  http://feeds.nature.com/~r/nature/rss/current/...   3.500000
# 139  http://feeds.nature.com/~r/nnano/rss/current/~...   3.320000
# 140  http://www.sciencemag.org/content/349/6244/147...   3.189655
# 141  http://feeds.nature.com/~r/nnano/rss/aop/~3/XJ...   3.142857
# 142  http://feeds.nature.com/~r/nature/rss/current/...   3.000000
# 143  http://feeds.nature.com/~r/nature/rss/current/...   3.000000
# 144  http://feeds.nature.com/~r/nature/rss/current/...   3.000000
# 145  http://feeds.nature.com/~r/nature/rss/current/...   3.000000
# 146  http://feeds.nature.com/~r/nature/rss/current/...   3.000000
# 147  http://www.sciencemag.org/content/349/6244/125...   2.900990
# 148  http://www.sciencemag.org/content/349/6244/141...   2.871429
# 149  http://feeds.nature.com/~r/nmat/rss/aop/~3/bjN...   2.840000
# 150  http://feeds.nature.com/~r/nature/rss/current/...   2.600000
# 151  http://www.sciencemag.org/content/349/6244/144...   2.565217
# 152  http://feeds.nature.com/~r/nature/rss/current/...   2.500000
# 153  http://feeds.nature.com/~r/nature/rss/current/...   2.323529
# 154  http://feeds.nature.com/~r/nnano/rss/current/~...   2.142857
# 155  http://www.sciencemag.org/content/349/6244/146...   1.946667
# 156  http://feeds.nature.com/~r/nmat/rss/aop/~3/vSp...   1.945946
# 157  http://feeds.nature.com/~r/nphys/rss/current/~...   1.650000
# 158  http://feeds.nature.com/~r/nphoton/rss/current...   1.611111
# 159  http://feeds.nature.com/~r/nature/rss/current/...   1.294118
# 160  http://feeds.nature.com/~r/nphys/rss/aop/~3/Ve...   1.263158
# 161  http://www.sciencemag.org/content/349/6244/147...   1.230769
# 162  http://feeds.nature.com/~r/nature/rss/current/...   0.888889
# 163  http://feeds.nature.com/~r/nnano/rss/current/~...   0.424242
# 164  http://feeds.nature.com/~r/nphys/rss/aop/~3/Pg...   0.379310
# 165  http://feeds.nature.com/~r/nnano/rss/aop/~3/Rk...   0.222222
# 166  http://feeds.nature.com/~r/nature/rss/current/...   0.176471
# 167  http://feeds.nature.com/~r/nmat/rss/aop/~3/HKZ...   0.000000
#
# [168 rows x 3 columns]
