# %% [markdown]
# # Getting recommendations
#
# **Important**: Make sure you have a csv of your zotero library and a text file with your feedly client token in the inputs folder.

# %%
from article_recommender.load_zotero import ZoteroLibrary
from article_recommender.training import TrainingData
from article_recommender.feedly_connector import FeedlyStream

# %% [markdown]
# If you have never loaded the nltk stopwords corpus before run the code below:

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/steve/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# First load your zotero library.

# %%
library = ZoteroLibrary()
library.read_library('inputs/zotero_library.csv')

# %% [markdown]
# Load the library into a training data set.

# %%
train_data = TrainingData(library.get_library())

# %% [markdown]
# Train a count vectorizer (bag of words) based on the training data to prepare for scoring articles.

# %%
train_data.train_count_vectorizer();

# %% [markdown]
# Load articles from feedly that you would like to score. Category should be the category on feedly where you put your journal article feeds. You can load up to 1000 articles per stream (rss feed). You can also load multiple categories by running the load_category function for each category.

# %%
# %%capture 
# ^^ Hides the SSL warnings from the requests library
with open('inputs/feedly_client_token.txt', 'r') as f:
    FEEDLY_CLIENT_TOKEN = f.readline()

rss_articles = FeedlyStream(FEEDLY_CLIENT_TOKEN)
rss_articles.load_category(category='Journals', articles_per_stream=5);

# %% [markdown]
# Rank all the articles in loaded categories based on the trained vectorizer from train_data. The result is a pandas data frame that can be further manipulated or output to a file.

# %%
results = rss_articles.rank_all(train_data)
results
# Out:
#                                                 Title  \
# 0                            Analog optical computing
# 1    2D materials: Single photons at room temperature
# 2   Quantum emission from hexagonal boron nitride ...
# 3   Matter-wave interference: Nanomechanical answe...
# 4             High-harmonic generation: Vacuum effect
# 5   Deep blue phosphorescent organic light-emittin...
# 6             Optical communications: Underwater link
# 7        Towards a calcium-based rechargeable battery
# 8              Microtissues: Assembled using DNA glue
# 9   Atomic-scale electronic structure of the cupra...
# 10  Emergent reduced dimensionality by vertex frus...
# 11  Evidence of an odd-parity hidden order in a sp...
# 12                                  A solar checklist
# 13              A checklist for photovoltaic research
# 14                             Brownian Carnot engine
# 15            Hybrid perovskites: Cationic vibrations
# 16        DNA nanotechnology: Nanoscale cable tacking
# 17                      Graphene: Hierarchical fibres
# 18                    Catalysis: Pinpointing platinum
# 19  Placing molecules with Bohr radius resolution ...
# 20   Fast diffusion of water nanodroplets on graphene
# 21  [In Depth] Europe's Mars rover to target ancie...
# 22  Non-Boolean computing with nanomagnets for com...
# 23                 Mechanics of fire ant aggregations
# 24              Our choice from the recent literature
# 25  [In Depth] Lifelong memories may reside in net...
# 26                                   Jin et al. reply
# 27            The week in science: 23–29 October 2015
# 28  Observation of a transition from a topological...
# 29                                     Fifty years on
# 30                         Technologies and religions
# 31                     [In Brief] This week's section
# 32                                      Burst bubbles
# 33  [Errata] Erratum for the Report “Base triplet ...
# 34  Giant photodetector arrays underpin Nobel success
# 35  Design principles for maximizing photovoltage ...
# 36  Institutions: Revive universities of the Musli...
# 37                 [Editorial] Zero tolerance. Period
# 38    Microbiology: Create a global microbiome effort
# 39  Macromolecular crowding creates heterogeneous ...
#
#                                                   Url      Score
# 0   http://feeds.nature.com/~r/nphoton/rss/current...  23.750000
# 1   http://feeds.nature.com/~r/nnano/rss/aop/~3/It...  23.086957
# 2   http://feeds.nature.com/~r/nnano/rss/aop/~3/U0...  21.315217
# 3   http://feeds.nature.com/~r/nnano/rss/current/~...  20.095238
# 4   http://feeds.nature.com/~r/nphoton/rss/current...  19.800000
# 5   http://feeds.nature.com/~r/nmat/rss/aop/~3/LC6...  17.206897
# 6   http://feeds.nature.com/~r/nphoton/rss/current...  16.888889
# 7   http://feeds.nature.com/~r/nmat/rss/aop/~3/BEk...  16.806818
# 8   http://feeds.nature.com/~r/nmat/rss/current/~3...  16.700000
# 9   http://feeds.nature.com/~r/nphys/rss/aop/~3/K0...  16.354430
# 10  http://feeds.nature.com/~r/nphys/rss/aop/~3/mk...  15.550459
# 11  http://feeds.nature.com/~r/nphys/rss/aop/~3/Gt...  15.428571
# 12  http://feeds.nature.com/~r/nphoton/rss/current...  15.000000
# 13  http://feeds.nature.com/~r/nmat/rss/current/~3...  14.285714
# 14  http://feeds.nature.com/~r/nphys/rss/aop/~3/t_...  13.327586
# 15  http://feeds.nature.com/~r/nmat/rss/current/~3...  13.111111
# 16  http://feeds.nature.com/~r/nnano/rss/current/~...  12.850000
# 17  http://feeds.nature.com/~r/nmat/rss/current/~3...  12.625000
# 18  http://feeds.nature.com/~r/nmat/rss/current/~3...  12.625000
# 19  http://feeds.nature.com/~r/nnano/rss/aop/~3/rs...  12.458333
# 20  http://feeds.nature.com/~r/nmat/rss/aop/~3/Vq7...  12.200000
# 21  http://www.sciencemag.org/content/350/6260/490...   5.866071
# 22  http://feeds.nature.com/~r/nnano/rss/aop/~3/6X...   5.416667
# 23  http://feeds.nature.com/~r/nmat/rss/aop/~3/gyD...   5.301075
# 24  http://feeds.nature.com/~r/nnano/rss/current/~...   5.000000
# 25  http://www.sciencemag.org/content/350/6260/491...   4.272727
# 26  http://feeds.nature.com/~r/nature/rss/current/...   4.205882
# 27  http://feeds.nature.com/~r/nature/rss/current/...   3.500000
# 28  http://feeds.nature.com/~r/nphys/rss/aop/~3/4b...   3.280000
# 29  http://feeds.nature.com/~r/nnano/rss/current/~...   3.142857
# 30  http://feeds.nature.com/~r/nnano/rss/current/~...   3.133333
# 31  http://www.sciencemag.org/content/350/6260/488...   3.000000
# 32  http://feeds.nature.com/~r/nature/rss/current/...   2.500000
# 33  http://www.sciencemag.org/content/350/6260/aad...   2.187500
# 34  http://feeds.nature.com/~r/nphoton/rss/current...   2.181818
# 35  http://feeds.nature.com/~r/nmat/rss/aop/~3/dQ5...   2.000000
# 36  http://feeds.nature.com/~r/nature/rss/current/...   1.913043
# 37  http://www.sciencemag.org/content/350/6260/487...   1.733333
# 38  http://feeds.nature.com/~r/nature/rss/current/...   0.590909
# 39  http://feeds.nature.com/~r/nnano/rss/aop/~3/XW...   0.000000

# %% [markdown]
# ## Same as above but with the tf-idf vectorizer (term frequency inverse document frequency)

# %%
train_data.train_tfidf_vectorizer();

# %%
tfidf_results = rss_articles.rank_all(train_data, vectorizer='tfidf')
tfidf_results
# Out:
#                                                 Title  \
# 0   Quantum emission from hexagonal boron nitride ...
# 1   Evidence of an odd-parity hidden order in a sp...
# 2                              Brownian Carnot engine
# 3   Placing molecules with Bohr radius resolution ...
# 4   Atomic-scale electronic structure of the cupra...
# 5   Emergent reduced dimensionality by vertex frus...
# 6        Towards a calcium-based rechargeable battery
# 7   Deep blue phosphorescent organic light-emittin...
# 8    2D materials: Single photons at room temperature
# 9   [In Depth] Europe's Mars rover to target ancie...
# 10        DNA nanotechnology: Nanoscale cable tacking
# 11  Matter-wave interference: Nanomechanical answe...
# 12             Microtissues: Assembled using DNA glue
# 13                           Analog optical computing
# 14  [In Depth] Lifelong memories may reside in net...
# 15                 Mechanics of fire ant aggregations
# 16                                  A solar checklist
# 17            High-harmonic generation: Vacuum effect
# 18              A checklist for photovoltaic research
# 19            Optical communications: Underwater link
# 20   Fast diffusion of water nanodroplets on graphene
# 21                      Graphene: Hierarchical fibres
# 22                    Catalysis: Pinpointing platinum
# 23                     [In Brief] This week's section
# 24            Hybrid perovskites: Cationic vibrations
# 25  [Errata] Erratum for the Report “Base triplet ...
# 26                                   Jin et al. reply
# 27  Observation of a transition from a topological...
# 28  Design principles for maximizing photovoltage ...
# 29  Non-Boolean computing with nanomagnets for com...
# 30                 [Editorial] Zero tolerance. Period
# 31              Our choice from the recent literature
# 32                         Technologies and religions
# 33                                     Fifty years on
# 34                                      Burst bubbles
# 35            The week in science: 23–29 October 2015
# 36  Giant photodetector arrays underpin Nobel success
# 37  Institutions: Revive universities of the Musli...
# 38    Microbiology: Create a global microbiome effort
# 39  Macromolecular crowding creates heterogeneous ...
#
#                                                   Url      Score
# 0   http://feeds.nature.com/~r/nnano/rss/aop/~3/U0...  12.823589
# 1   http://feeds.nature.com/~r/nphys/rss/aop/~3/Gt...  12.603051
# 2   http://feeds.nature.com/~r/nphys/rss/aop/~3/t_...  11.440894
# 3   http://feeds.nature.com/~r/nnano/rss/aop/~3/rs...  11.438024
# 4   http://feeds.nature.com/~r/nphys/rss/aop/~3/K0...  11.360211
# 5   http://feeds.nature.com/~r/nphys/rss/aop/~3/mk...  11.344515
# 6   http://feeds.nature.com/~r/nmat/rss/aop/~3/BEk...  10.779973
# 7   http://feeds.nature.com/~r/nmat/rss/aop/~3/LC6...   9.980871
# 8   http://feeds.nature.com/~r/nnano/rss/aop/~3/It...   8.234957
# 9   http://www.sciencemag.org/content/350/6260/490...   7.412283
# 10  http://feeds.nature.com/~r/nnano/rss/current/~...   6.839660
# 11  http://feeds.nature.com/~r/nnano/rss/current/~...   6.140531
# 12  http://feeds.nature.com/~r/nmat/rss/current/~3...   6.132373
# 13  http://feeds.nature.com/~r/nphoton/rss/current...   5.711227
# 14  http://www.sciencemag.org/content/350/6260/491...   5.594196
# 15  http://feeds.nature.com/~r/nmat/rss/aop/~3/gyD...   5.354296
# 16  http://feeds.nature.com/~r/nphoton/rss/current...   5.290842
# 17  http://feeds.nature.com/~r/nphoton/rss/current...   5.262880
# 18  http://feeds.nature.com/~r/nmat/rss/current/~3...   5.243166
# 19  http://feeds.nature.com/~r/nphoton/rss/current...   5.069603
# 20  http://feeds.nature.com/~r/nmat/rss/aop/~3/Vq7...   4.853250
# 21  http://feeds.nature.com/~r/nmat/rss/current/~3...   4.836347
# 22  http://feeds.nature.com/~r/nmat/rss/current/~3...   4.836347
# 23  http://www.sciencemag.org/content/350/6260/488...   4.201576
# 24  http://feeds.nature.com/~r/nmat/rss/current/~3...   4.173454
# 25  http://www.sciencemag.org/content/350/6260/aad...   3.883414
# 26  http://feeds.nature.com/~r/nature/rss/current/...   3.399670
# 27  http://feeds.nature.com/~r/nphys/rss/aop/~3/4b...   3.358852
# 28  http://feeds.nature.com/~r/nmat/rss/aop/~3/dQ5...   3.050108
# 29  http://feeds.nature.com/~r/nnano/rss/aop/~3/6X...   3.049376
# 30  http://www.sciencemag.org/content/350/6260/487...   2.785644
# 31  http://feeds.nature.com/~r/nnano/rss/current/~...   2.134142
# 32  http://feeds.nature.com/~r/nnano/rss/current/~...   1.934426
# 33  http://feeds.nature.com/~r/nnano/rss/current/~...   1.869318
# 34  http://feeds.nature.com/~r/nature/rss/current/...   1.723020
# 35  http://feeds.nature.com/~r/nature/rss/current/...   1.667806
# 36  http://feeds.nature.com/~r/nphoton/rss/current...   1.503410
# 37  http://feeds.nature.com/~r/nature/rss/current/...   1.462082
# 38  http://feeds.nature.com/~r/nature/rss/current/...   1.059320
# 39  http://feeds.nature.com/~r/nnano/rss/aop/~3/XW...   0.000000
